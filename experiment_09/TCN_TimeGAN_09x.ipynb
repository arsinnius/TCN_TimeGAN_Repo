# %% [markdown]
# <font size="+3">Time-series Generative Adversarial Network (TimeGAN): Experiment 9</font>
# from "Machine Learning for Algorithmic Trading" 2nd Ed. by Stefan Jansen

# %% [markdown]
# Adapted from the excellent paper by Jinsung Yoon, Daniel Jarrett, and Mihaela van der Schaar:
# [Time-series Generative Adversarial Networks](https://papers.nips.cc/paper/8789-time-series-generative-adversarial-networks),
# Neural Information Processing Systems (NeurIPS), 2019.
#
# - Last updated Date: April 24th 2020
# - [Original code](https://bitbucket.org/mvdschaar/mlforhealthlabpub/src/master/alg/timegan/) author: Jinsung Yoon (jsyoon0823@gmail.com)

# %%
# %cd g:\My Drive\Repositoritories
# Out:
# g:\My Drive\Repositoritories

# %% [markdown]
# # Imports & Settings

# %% [markdown]
# ## Imports

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from pathlib import Path
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm

import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import (GRU, Dense, 
                                     RNN, GRUCell, Input, 
                                     Permute, Lambda)
from tensorflow.keras.losses import BinaryCrossentropy, MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import TensorBoard
from tensorflow.keras.utils import plot_model

import datetime as dt
import numpy as np
import os
import pandas as pd
import time

import matplotlib.pyplot as plt 
import seaborn as sns

sns.set_style('white')

# %%
# !pip3 install --upgrade tables
# !pip3 install keras-tcn --no-dependencies
# Out:
# Requirement already satisfied: tables in c:\users\arsin\anaconda3\envs\timegan\lib\site-packages (3.7.0)
# Requirement already satisfied: numexpr>=2.6.2 in c:\users\arsin\anaconda3\envs\timegan\lib\site-packages (from tables) (2.8.3)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\arsin\anaconda3\envs\timegan\lib\site-packages (from tables) (1.22.3)
# Requirement already satisfied: packaging in c:\users\arsin\anaconda3\envs\timegan\lib\site-packages (from tables) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\arsin\anaconda3\envs\timegan\lib\site-packages (from packaging->tables) (3.0.9)
# Requirement already satisfied: keras-tcn in c:\users\arsin\anaconda3\envs\timegan\lib\site-packages (3.5.0)

# %% [markdown]
# ## GPU

# %%
gpu_devices = tf.config.experimental.list_physical_devices('GPU')
if gpu_devices:
    print('Using GPU')
    tf.config.experimental.set_memory_growth(gpu_devices[0], True)
else:
    print('Using CPU')
# Out:
# Using CPU

# %% [markdown]
# ## Parameters

# %%
results_path = Path('./TCN_TimeGAN_Repo')
if not results_path.exists():
    results_path.mkdir()

# %%
os.chdir(results_path)

# %%
from src.params_09 import ( experiment, 
                                        ## Data Parameters
                                        data_file,
                                        ts_names,
                                        start_date,
                                        end_date,

                                        ## Parameters
                                        n_seq, 
                                        seq_len,
                                        batch_size,
                                        train_steps,
                                        gamma,

                                        ##  Network Parameters
                                        hidden_dim,
                                        latent_dim,
                                        n_layers_disc,
                                        n_layers_supv,

                                        ## Generic Loss Functions
                                        mse,
                                        bce,

                                        ## Optimizers
                                        autoencoder_optimizer,
                                        embedding_optimizer,
                                        discriminator_optimizer,
                                        generator_optimizer,
                                        supervisor_optimizer,

                                        ## Pooling Parameters
                                        pooler,
                                        latent_sample_rate )

# %%
os.chdir('../')

# %% [markdown]
# # Experiment Path

# %%
log_dir = results_path / f'experiment_{experiment:02}'
if not log_dir.exists():
    log_dir.mkdir(parents=True)

# %%
sample_dir = log_dir / 'samples'
if not sample_dir.exists():
    sample_dir.mkdir(parents=True)

# %%
evals_dir = log_dir / 'evals'
if not evals_dir.exists():
    evals_dir.mkdir(parents=True)

# %%
data_dir = log_dir / 'data'
if not data_dir.exists():
    data_dir.mkdir(parents=True)

# %%
hdf_store = log_dir / f'TimeSeriesGAN_{experiment:02}.h5'

# %% [markdown]
# # Prepare Data

# %% [markdown]
# ## Get Data

# %%
u1 = os.path.join(data_dir, data_file)
u2 = os.path.abspath(u1)
data = pd.read_csv(u2)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    512 non-null    object
#  1   PDSI    512 non-null    float64
#  2   PHDI    512 non-null    float64
#  3   PMDI    512 non-null    float64
#  4   PZI     512 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 20.1+ KB

# %%
data.head()
# Out:
#      date  PDSI  PHDI  PMDI   PZI
# 0  1895Q1 -0.86 -0.86 -0.86 -2.59
# 1  1895Q2 -1.27 -1.27 -1.27 -1.88
# 2  1895Q3  0.42 -0.78  0.42  0.58
# 3  1895Q4 -0.90 -0.90 -0.90 -2.23
# 4  1896Q1 -1.34 -1.34 -1.34 -2.02

# %%
data.tail()
# Out:
#        date   PDSI   PHDI   PMDI    PZI
# 507  2021Q4   5.80   5.83   5.83  -1.88
# 508  2022Q1 -99.99   4.06   3.94   2.02
# 509  2022Q2 -99.99 -99.99 -99.99 -99.99
# 510  2022Q3 -99.99 -99.99 -99.99 -99.99
# 511  2022Q4 -99.99 -99.99 -99.99 -99.99

# %%
data.to_hdf(hdf_store, 'data/real')

# %% [markdown]
# ## Plot Series

# %%
tickers = ts_names

# %%
df = pd.read_hdf(hdf_store, 'data/real')
df = df.set_index(['date'])     # use DateTime index

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 512 entries, 1895Q1 to 2022Q4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   PDSI    512 non-null    float64
#  1   PHDI    512 non-null    float64
#  2   PMDI    512 non-null    float64
#  3   PZI     512 non-null    float64
# dtypes: float64(4)
# memory usage: 20.0+ KB

# %%
axes = df.loc[start_date:end_date].plot(subplots=True,
                                        figsize=(14, 6),
                                        layout=(n_seq, 2),
                                        title=tickers,
                                        legend=False,
                                        rot=0,
                                        lw=1, 
                                        color='k')
for ax in axes.flatten():
    ax.set_xlabel('')

plt.suptitle('Drought Indices')
plt.gcf().tight_layout()
sns.despine();

# %% [markdown]
# ## Correlation

# %%
df.corr()
# Out:
#           PDSI      PHDI      PMDI       PZI
# PDSI  1.000000  0.856780  0.860684  0.839309
# PHDI  0.856780  1.000000  0.996446  0.951904
# PMDI  0.860684  0.996446  1.000000  0.959516
# PZI   0.839309  0.951904  0.959516  1.000000

# %%
sns.clustermap(df.corr(),
               annot=True,
               fmt='.2f',
               cmap=sns.diverging_palette(h_neg=20,
                                          h_pos=220), center=0);

# %% [markdown]
# ## Normalize Data

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(df).astype(np.float32)

# %% [markdown]
# ## Create rolling window sequences

# %%
data = []
for i in range(len(df)-seq_len): 
  data.append(scaled_data[i:i + seq_len])
n_windows = len(data)
print(n_windows)
# Out:
# 332

# %%
[len(data), data[0].shape]
# Out:
# [332, (180, 4)]

# %% [markdown]
# ## Create tf.data.Dataset

# %%
real_series = (tf.data.Dataset
               .from_tensor_slices(data)
               .shuffle(buffer_size=n_windows)
               .batch(batch_size))
real_series_iter = iter(real_series.repeat())

# %% [markdown]
# ## Set up random series generator

# %%
def make_random_data():
    while True:
        yield np.random.uniform(low=0, high=1, size=(seq_len, n_seq))

# %% [markdown]
# We use the Python generator to feed a `tf.data.Dataset` that continues to call the random number generator as long as necessary and produces the desired batch size.

# %%
random_series = iter(tf.data.Dataset
                     .from_generator(make_random_data, output_types=tf.float32)
                     .batch(batch_size)
                     .repeat())

# %% [markdown]
# # TimeGAN Components

# %% [markdown]
# The design of the supervisor and discriminator follows the author's sample code. The embedder, recovery and generator are based on the Temporal Convolutional Network (TCN).

# %% [markdown]
# ## Set up logger

# %%
writer = tf.summary.create_file_writer(log_dir.as_posix())

# %% [markdown]
# ## Block generator (RNN)

# %%
def make_rnn(input_shape, n_layers, hidden_units, output_units, name):
    return Sequential([Input(shape=input_shape)] +      
                      [GRU(units=hidden_units,
                           return_sequences=True,
                           name=f'GRUvy_{i + 1}') for i in range(n_layers)] +
                      [Dense(units=output_units,
                             activation='sigmoid',
                             name='OUT')], name=name)

# %%
from src.train_fns import make_rnn

# %% [markdown]
# ## Generator (TCN), Discriminator and Supervisor (RNN)

# %%
from src.tcn_ae import TCN_AE

tcn_ae = TCN_AE(ts_len=seq_len, ts_dimension=n_seq, latent_sample_rate=latent_sample_rate, pooler=pooler)
tcn_generator = tcn_ae.build_encoder()
# Out:
# Model: "TCN_Autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 180, 4)]          0
#
#  TCN_Encoder (Functional)    (None, 45, 8)             74068
#
#  TCN_Decoder (Functional)    (None, 180, 4)            75664
#
# =================================================================
# Total params: 149,732
# Trainable params: 149,732
# Non-trainable params: 0
# _________________________________________________________________
# Model: "TCN_Encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 180, 4)]          0
#
#  tcn-enc (TCN)               (None, 180, 20)           73900
#
#  conv1d_1 (Conv1D)           (None, 180, 8)            168
#
#  max_pooling1d_1 (MaxPooling  (None, 45, 8)            0
#  1D)
#
#  activation_1 (Activation)   (None, 45, 8)             0
#
# =================================================================
# Total params: 74,068
# Trainable params: 74,068
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(tcn_generator, show_shapes=True)

# %%
supervisor = make_rnn(input_shape=[45, 8], 
                          n_layers=n_layers_supv, 
                          hidden_units=latent_dim, 
                          output_units=latent_dim, 
                          name='Supervisor')

# %%
plot_model(supervisor, show_shapes=True)

# %%
discriminator = make_rnn(input_shape=[45, 8],
                         n_layers=n_layers_disc, 
                         hidden_units=hidden_dim, 
                         output_units=1, 
                         name='Discriminator')

# %%
plot_model(discriminator, show_shapes=True)

# %% [markdown]
# ## Input place holders

# %%
X = Input(shape=[seq_len, n_seq], name='RealData')
Z = Input(shape=[seq_len, n_seq], name='RandomData')

# %%
tcn_generator(X).shape
# Out:
# TensorShape([None, 45, 8])

# %%
discriminator(tcn_generator(X)).shape
# Out:
# TensorShape([None, 45, 1])

# %%
supervisor(tcn_generator(X)).shape
# Out:
# TensorShape([None, 45, 8])

# %% [markdown]
# # TimeGAN Training

# %% [markdown]
# # Phase 1: Autoencoder Training

# %% [markdown]
# ## Architecture TCN

# %%
embedder = tcn_ae.build_encoder()
recovery = tcn_ae.build_decoder()
# Out:
# Model: "TCN_Encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_input (InputLayer)  [(None, 180, 4)]          0
#
#  tcn-enc (TCN)               (None, 180, 20)           73900
#
#  conv1d_2 (Conv1D)           (None, 180, 8)            168
#
#  max_pooling1d_2 (MaxPooling  (None, 45, 8)            0
#  1D)
#
#  activation_2 (Activation)   (None, 45, 8)             0
#
# =================================================================
# Total params: 74,068
# Trainable params: 74,068
# Non-trainable params: 0
# _________________________________________________________________
# Model: "TCN_Decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_output (InputLayer)  [(None, 45, 8)]          0
#
#  up_sampling1d_1 (UpSampling  (None, 180, 8)           0
#  1D)
#
#  tcn-dec (TCN)               (None, 180, 20)           75580
#
#  dense_1 (Dense)             (None, 180, 4)            84
#
# =================================================================
# Total params: 75,664
# Trainable params: 75,664
# Non-trainable params: 0
# _________________________________________________________________

# %%
H = embedder(X)
X_tilde = recovery(H)

autoencoder = Model(inputs=X,
                    outputs=X_tilde,
                    name='Autoencoder')
autoencoder.summary()
# Out:
# Model: "Autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RealData (InputLayer)       [(None, 180, 4)]          0
#
#  TCN_Encoder (Functional)    (None, 45, 8)             74068
#
#  TCN_Decoder (Functional)    (None, 180, 4)            75664
#
# =================================================================
# Total params: 149,732
# Trainable params: 149,732
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Autoencoder Training Step

# %%
@tf.function
def train_autoencoder_init(x):
    with tf.GradientTape() as tape:
        x_tilde = autoencoder(x)        
        embedding_loss_t0 = mse(x, x_tilde)
        e_loss_0 = 10 * tf.sqrt(embedding_loss_t0)
        
    var_list = embedder.trainable_variables + recovery.trainable_variables
    gradients = tape.gradient(e_loss_0, var_list)
    autoencoder_optimizer.apply_gradients(zip(gradients, var_list))
    return tf.sqrt(embedding_loss_t0)

# %% [markdown]
# ## Autoencoder Training Loop

# %%
for step in tqdm(range(train_steps)):
    X_ = next(real_series_iter)
    step_e_loss_t0 = train_autoencoder_init(X_)
    with writer.as_default():
        tf.summary.scalar('Loss Autoencoder Init', step_e_loss_t0, step=step)
# Out:
# 100%|██████████| 10000/10000 [17:52:07<00:00,  6.43s/it]

# %% [markdown]
# ## Persist Autoencoder Model

# %%
autoencoder.save(log_dir / 'autoencoder')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Function `_wrapped_model` contains input name(s) RealData with unsupported characters which will be renamed to realdata in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, residual_block_0_layer_call_fn, residual_block_0_layer_call_and_return_conditional_losses, residual_block_1_layer_call_fn, residual_block_1_layer_call_and_return_conditional_losses while saving (showing 5 of 187). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: TCN_TimeGAN_Repo\experiment_09\autoencoder\assets
# INFO:tensorflow:Assets written to: TCN_TimeGAN_Repo\experiment_09\autoencoder\assets

# %% [markdown]
# # Phase 2: Supervised training

# %%
autoencoder = tf.keras.models.load_model(log_dir / 'autoencoder')
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ## Supervisor Train Step

# %%
@tf.function
def train_supervisor(x):    
    with tf.GradientTape() as tape:
        h = embedder(x)
        h_hat_supervised = supervisor(h)
        g_loss_s = mse(h[:, 1:, :], h_hat_supervised[:, :-1, :])
    var_list = supervisor.trainable_variables
    gradients = tape.gradient(g_loss_s, var_list)
    supervisor_optimizer.apply_gradients(zip(gradients, var_list))
    return g_loss_s

# %% [markdown]
# ## Supervisor Training Loop

# %%
for step in tqdm(range(train_steps)):
    X_ = next(real_series_iter)
    step_g_loss_s = train_supervisor(X_)
    with writer.as_default():
        tf.summary.scalar('Loss Generator Supervised Init', step_g_loss_s, step=step)
# Out:
# 100%|██████████| 10000/10000 [22:36<00:00,  7.37it/s]

# %% [markdown]
# ## Persist Supervisor Model

# %%
supervisor.save(log_dir / 'supervisor')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses, gru_cell_1_layer_call_fn, gru_cell_1_layer_call_and_return_conditional_losses while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: TCN_TimeGAN_Repo\experiment_09\supervisor\assets
# INFO:tensorflow:Assets written to: TCN_TimeGAN_Repo\experiment_09\supervisor\assets

# %%
supervisor = tf.keras.models.load_model(log_dir / 'supervisor')
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# # Joint Training

# %% [markdown]
# ## Generator

# %% [markdown]
# ### Adversarial Architecture - Supervised

# %%
E_hat = tcn_generator(Z)
H_hat = supervisor(E_hat)
Y_fake = discriminator(H_hat)

adversarial_supervised = Model(inputs=Z,
                               outputs=Y_fake,
                               name='AdversarialNetSupervised')

# %%
E_hat.shape
# Out:
# TensorShape([None, 45, 8])

# %%
H_hat.shape
# Out:
# TensorShape([None, 45, 8])

# %%
adversarial_supervised.summary()
# Out:
# Model: "AdversarialNetSupervised"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RandomData (InputLayer)     [(None, 180, 4)]          0
#
#  TCN_Encoder (Functional)    (None, 45, 8)             74068
#
#  Supervisor (Sequential)     (None, 45, 8)             936
#
#  Discriminator (Sequential)  (None, 45, 1)             4529
#
# =================================================================
# Total params: 79,533
# Trainable params: 79,533
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(adversarial_supervised, show_shapes=True)

# %% [markdown]
# ### Adversarial Architecture in Latent Space

# %%
Y_fake_e = discriminator(E_hat)

adversarial_emb = Model(inputs=Z,
                    outputs=Y_fake_e,
                    name='AdversarialNet')

# %%
adversarial_emb.summary()
# Out:
# Model: "AdversarialNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RandomData (InputLayer)     [(None, 180, 4)]          0
#
#  TCN_Encoder (Functional)    (None, 45, 8)             74068
#
#  Discriminator (Sequential)  (None, 45, 1)             4529
#
# =================================================================
# Total params: 78,597
# Trainable params: 78,597
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(adversarial_emb, show_shapes=True)

# %% [markdown]
# ## Synthesizer

# %%
X_hat = recovery(H_hat)
synthesizer = Model(inputs=Z,
                       outputs=X_hat,
                       name='Synthesizer')

# %%
synthesizer.summary()
# Out:
# Model: "Synthesizer"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RandomData (InputLayer)     [(None, 180, 4)]          0
#
#  TCN_Encoder (Functional)    (None, 45, 8)             74068
#
#  Supervisor (Sequential)     (None, 45, 8)             936
#
#  TCN_Decoder (Functional)    (None, 180, 4)            75664
#
# =================================================================
# Total params: 150,668
# Trainable params: 150,668
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(synthesizer, show_shapes=True)

# %% [markdown]
# ### Moment Loss and Roughness Loss

# %%
def get_generator_moment_loss(y_true, y_pred):
    y_true_mean, y_true_var = tf.nn.moments(x=y_true, axes=[0])
    y_pred_mean, y_pred_var = tf.nn.moments(x=y_pred, axes=[0])
    g_loss_mean = tf.reduce_mean(tf.abs(y_true_mean - y_pred_mean))
    g_loss_var = tf.reduce_mean(tf.abs(tf.sqrt(y_true_var + 1e-6) - tf.sqrt(y_pred_var + 1e-6)))
    return g_loss_mean + g_loss_var

# %%
def get_roughness_loss(x,y):
  #
  t = (x - y).numpy()
  ts_loss = np.sum(np.sum(np.diff(t, n=2, axis=0)**2, axis=0)/len(x), axis=0)
  return sum(ts_loss)

# %% [markdown]
# ## Discriminator

# %% [markdown]
# ### Architecture: Real Data

# %%
Y_real = discriminator(H)
discriminator_model = Model(inputs=X,
                            outputs=Y_real,
                            name='DiscriminatorReal')

# %%
discriminator_model.summary()
# Out:
# Model: "DiscriminatorReal"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  RealData (InputLayer)       [(None, 180, 4)]          0
#
#  TCN_Encoder (Functional)    (None, 45, 8)             74068
#
#  Discriminator (Sequential)  (None, 45, 1)             4529
#
# =================================================================
# Total params: 78,597
# Trainable params: 78,597
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(discriminator_model, show_shapes=True)

# %% [markdown]
# ## Generator Train Step

# %%
@tf.function
def train_generator(x, z):
    with tf.GradientTape() as tape:
        y_fake = adversarial_supervised(z)
        generator_loss_unsupervised = bce(y_true=tf.ones_like(y_fake),
                                          y_pred=y_fake)

        y_fake_e = adversarial_emb(z)
        generator_loss_unsupervised_e = bce(y_true=tf.ones_like(y_fake_e),
                                            y_pred=y_fake_e)
        h = embedder(x)
        h_hat_supervised = supervisor(h)
        generator_loss_supervised = mse(h[:, 1:, :], h_hat_supervised[:, 1:, :])

        x_hat = synthesizer(z)
        generator_moment_loss = get_generator_moment_loss(x, x_hat)
        generator_roughness_loss = get_roughness_loss(x, x_hat)
        
        generator_loss = (generator_loss_unsupervised +
                          generator_loss_unsupervised_e +
                          100 * tf.sqrt(generator_loss_supervised) +
                          100 * generator_moment_loss +
                          generator_roughness_loss)
    
    var_list = tcn_generator.trainable_variables + supervisor.trainable_variables
    gradients = tape.gradient(generator_loss, var_list)
    generator_optimizer.apply_gradients(zip(gradients, var_list))
    return generator_loss_unsupervised, generator_loss_supervised, generator_moment_loss, generator_roughness_loss

# %% [markdown]
# ## Embedding Train Step

# %%
@tf.function
def train_embedder(x):
    with tf.GradientTape() as tape:
        h = embedder(x)
        h_hat_supervised = supervisor(h)
        generator_loss_supervised = mse(h[:, 1:, :], h_hat_supervised[:, 1:, :])

        x_tilde = autoencoder(x)
        embedding_loss_t0 = mse(x, x_tilde)
        e_loss = 10 * tf.sqrt(embedding_loss_t0) + 0.1 * generator_loss_supervised

    var_list = embedder.trainable_variables + recovery.trainable_variables
    gradients = tape.gradient(e_loss, var_list)
    embedding_optimizer.apply_gradients(zip(gradients, var_list))
    return tf.sqrt(embedding_loss_t0)

# %% [markdown]
# ## Discriminator Train Step

# %%
def get_discriminator_loss(x, z):
    y_real = discriminator_model(x)
    discriminator_loss_real = bce(y_true=tf.ones_like(y_real),
                                  y_pred=y_real)

    y_fake = adversarial_supervised(z)
    discriminator_loss_fake = bce(y_true=tf.zeros_like(y_fake),
                                  y_pred=y_fake)

    y_fake_e = adversarial_emb(z)
    discriminator_loss_fake_e = bce(y_true=tf.zeros_like(y_fake_e),
                                    y_pred=y_fake_e)
    return (discriminator_loss_real +
            discriminator_loss_fake +
            gamma * discriminator_loss_fake_e)

# %%
@tf.function
def train_discriminator(x, z):
    with tf.GradientTape() as tape:
        discriminator_loss = get_discriminator_loss(x, z)

    var_list = discriminator.trainable_variables
    gradients = tape.gradient(discriminator_loss, var_list)
    discriminator_optimizer.apply_gradients(zip(gradients, var_list))
    return discriminator_loss

# %% [markdown]
# ## Joint Training Loop

# %%
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
min_loss = np.inf
patience = 4
brk_crit = 1e-4
wait = 0

# %%
tf.config.run_functions_eagerly(True)

step_g_loss_u = step_g_loss_s = step_g_loss_v = step_g_loss_r = step_e_loss_t0 = step_d_loss = 0
for step in range(train_steps):
    # Train generator (twice as often as discriminator)
    for kk in range(2):        
        Z_ = next(random_series)
        X_ = next(real_series_iter)
        while X_.shape != Z_.shape:
            X_ = next(real_series_iter)

        # Train generator
        step_g_loss_u, step_g_loss_s, step_g_loss_v, step_g_loss_r = train_generator(X_, Z_)
        # Train embedder
        step_e_loss_t0 = train_embedder(X_)
        
    X_ = next(real_series_iter)
    Z_ = next(random_series)
    step_d_loss = get_discriminator_loss(X_, Z_)
    if step_d_loss > 0.15:
        step_d_loss = train_discriminator(X_, Z_)

    if step % 100 == 0: 
        print(f'{step:6,.0f} | d_loss: {step_d_loss:6.4f} | g_loss_u: {step_g_loss_u:6.4f} | '
              f'g_loss_s: {step_g_loss_s:6.6f} | g_loss_v: {step_g_loss_v:6.4f} | g_loss_r: {step_g_loss_r:6.4f} | e_loss_t0: {step_e_loss_t0:6.4f}')
        
        wait += 1
        if min_loss - step_g_loss_s >= brk_crit:
          min_loss =  step_g_loss_s
          wait = 0
        if wait >= patience:
          break
        
    with writer.as_default():
        tf.summary.scalar('G Loss S', step_g_loss_s, step=step)
        tf.summary.scalar('G Loss U', step_g_loss_u, step=step)
        tf.summary.scalar('G Loss V', step_g_loss_v, step=step)
        tf.summary.scalar('G Loss R', step_g_loss_r, step=step)
        tf.summary.scalar('E Loss T0', step_e_loss_t0, step=step)
        tf.summary.scalar('D Loss', step_d_loss, step=step)  
                               
synthesizer.save(log_dir / 'synthesizer')
# Out:
#      0 | d_loss: 1.6422 | g_loss_u: 0.7607 | g_loss_s: 0.013255 | g_loss_v: 0.0160 | g_loss_r: 4.7601 | e_loss_t0: 0.0069
#    100 | d_loss: 1.4148 | g_loss_u: 0.7136 | g_loss_s: 0.000106 | g_loss_v: 0.0160 | g_loss_r: 4.9834 | e_loss_t0: 0.0068
#    200 | d_loss: 1.3912 | g_loss_u: 0.7027 | g_loss_s: 0.000040 | g_loss_v: 0.0159 | g_loss_r: 4.4522 | e_loss_t0: 0.0068
#    300 | d_loss: 1.3155 | g_loss_u: 1.0746 | g_loss_s: 0.000026 | g_loss_v: 0.0159 | g_loss_r: 4.5702 | e_loss_t0: 0.0068
#    400 | d_loss: 1.3987 | g_loss_u: 0.5769 | g_loss_s: 0.000019 | g_loss_v: 0.0166 | g_loss_r: 5.3274 | e_loss_t0: 0.0068
#    500 | d_loss: 0.3631 | g_loss_u: 4.1968 | g_loss_s: 0.000016 | g_loss_v: 0.0165 | g_loss_r: 4.8157 | e_loss_t0: 0.0068
# WARNING:absl:Function `_wrapped_model` contains input name(s) RandomData with unsupported characters which will be renamed to randomdata in the SavedModel.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, restored_function_body, restored_function_body, restored_function_body, restored_function_body while saving (showing 5 of 169). These functions will not be directly callable after loading.
# WARNING:absl:<keras.saving.saved_model.load.Lambda object at 0x000001E716845A30> has the same name 'Lambda' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Lambda'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Lambda object at 0x000001E716845F10> has the same name 'Lambda' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Lambda'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E71685D130> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E71685D970> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E716867460> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Lambda object at 0x000001E716867E50> has the same name 'Lambda' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Lambda'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E7168713D0> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E716871EB0> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Lambda object at 0x000001E71687D970> has the same name 'Lambda' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Lambda'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E71687DEB0> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E716888A90> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Lambda object at 0x000001E716891550> has the same name 'Lambda' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Lambda'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E716891A90> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E71689C670> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Lambda object at 0x000001E7168A7130> has the same name 'Lambda' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Lambda'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E7168A7670> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E7168B4250> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E7168B4F70> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E7168BE820> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E7168C63D0> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Lambda object at 0x000001E7168C6E50> has the same name 'Lambda' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Lambda'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E7168CE3D0> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E7168CEF70> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Lambda object at 0x000001E7168DBA30> has the same name 'Lambda' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Lambda'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E7168DBF70> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E7168E5B50> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Lambda object at 0x000001E7168EE610> has the same name 'Lambda' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Lambda'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E7168EEB50> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E7168FA730> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Lambda object at 0x000001E7169041F0> has the same name 'Lambda' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Lambda'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E716904730> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.saving.saved_model.load.Conv1D object at 0x000001E716910310> has the same name 'Conv1D' as a built-in Keras object. Consider renaming <class 'keras.saving.saved_model.load.Conv1D'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
plot_model(recovery, show_shapes=True)

# %%
plot_model(synthesizer, show_shapes=True)

# %%
plot_model(supervisor, show_shapes=True)

# %%
synthesizer = tf.keras.models.load_model(log_dir / 'synthesizer')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_40088\1457735898.py in <module>
# ----> 1 synthesizer = tf.keras.models.load_model(log_dir / 'synthesizer')
#
# c:\Users\arsin\anaconda3\envs\timeGAN\lib\site-packages\keras\utils\traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# c:\Users\arsin\anaconda3\envs\timeGAN\lib\site-packages\keras\engine\base_layer.py in input_spec(self, value)
#    1150     for v in tf.nest.flatten(value):
#    1151       if v is not None and not isinstance(v, input_spec.InputSpec):
# -> 1152         raise TypeError('Layer input_spec must be an instance of InputSpec. '
#    1153                         'Got: {}'.format(v))
#    1154     self._input_spec = value
#
# TypeError: Layer input_spec must be an instance of InputSpec. Got: <keras.initializers.initializers_v2.Zeros object at 0x000001E7222F9DC0>

# %%
real_data = np.stack(data)
real_data.shape
# Out:
# (332, 180, 4)

# %% [markdown]
# # Generate Synthetic Data

# %%
generated_data = []
for i in range(int(512/128)):
    Z_ = next(random_series)
    d = synthesizer(Z_)
    generated_data.append(d)

# %%
generated_data = np.array(np.vstack(generated_data))
generated_data.shape
# Out:
# (512, 180, 4)

# %%
np.save(log_dir / 'generated_data.npy', generated_data)

# %% [markdown]
# ## Rescale

# %%
generated_data = (scaler.inverse_transform(generated_data
                                           .reshape(-1, n_seq))
                  .reshape(-1, seq_len, n_seq))
generated_data.shape
# Out:
# (512, 180, 4)

# %%
real_data = (scaler.inverse_transform(np.stack(data)
                                           .reshape(-1, n_seq))
                  .reshape(-1, seq_len, n_seq))
real_data.shape
# Out:
# (332, 180, 4)

# %% [markdown]
# ## Persist Data

# %%
with pd.HDFStore(hdf_store) as store:
    store.put('data/synthetic', pd.DataFrame(generated_data.reshape(-1, n_seq),
                                             columns=tickers))

# %% [markdown]
# ## Plot sample Series

# %%
import os

# %%
generated_data.shape
# Out:
# (512, 180, 4)

# %%
real_data.shape
# Out:
# (332, 180, 4)

# %%
n_init = 5
n_plots = 5

for n in range(n_init, n_init + n_plots):
  print("\nSample Plot: %d" % (n + 1))
  fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(14, 7))
  axes = axes.flatten()
  
  idx = np.random.randint(len(real_data))
  synthetic = generated_data[idx]
  real = real_data[idx]

  for j, ticker in enumerate(tickers):
      (pd.DataFrame({'Real': real[:, j],
                    'Synthetic': synthetic[:,j]})
      .plot(ax=axes[j],
            title=ticker,
            secondary_y='Synthetic', style=['-', '--'],
            lw=1))
  sns.despine()

  fig.tight_layout()
  plt.show()
  f_name = os.path.join(log_dir, "samples", "sample_" + str(n + 1 ) + ".png")
  fig.savefig(f_name)
# Out:
# Sample Plot: 6
# Sample Plot: 7
# Sample Plot: 8
# Sample Plot: 9
# Sample Plot: 10

# %%
np.sum(np.diff(real - synthetic, n=2, axis=0)**2, axis=0)/180
# Out:
# array([24.723362, 16.187386, 18.225237, 69.575676], dtype=float32)

# %%
np.sum(np.diff(real, n=2, axis=0)**2, axis=0)/180
# Out:
# array([12.735094,  8.254612, 11.945471, 42.374413], dtype=float32)

# %%
np.sum(np.diff(synthetic, n=2, axis=0)**2, axis=0)/180
# Out:
# array([13.239264,  8.596266,  6.356606, 26.874086], dtype=float32)

# %%
def get_rough_loss(x,y):
  ts_loss = np.sum(np.diff(x - y, n=2, axis=0)**2, axis=0)/len(x)
  return sum(ts_loss)

# %%
get_rough_loss(real, synthetic)
# Out:
# 128.71166038513184
